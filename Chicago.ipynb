# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import json

# %% [markdown]
# # EXTRACT CHICAGO CRIME DATA (CSV)

# %%
# Input Crime File (CSV)
crime_df = pd.read_csv('chicago_crime.csv')
crime_df.head()
# Out:
#          ID Case Number                    Date               Block  IUCR  \
# 0  11552657    JC100019  12/31/2018 11:30:00 PM  004XX S CLINTON ST  0313
# 1  11552595    JB574410  12/31/2018 11:27:00 PM     041XX W 79TH ST  051A
# 2  11552585    JB574353  12/31/2018 10:50:00 PM     008XX W 59TH ST  0557
# 3  11552598    JC100015  12/31/2018 10:33:00 PM   060XX S MASON AVE  051B
# 4  11553505    JC101102  12/31/2018 10:07:00 PM   078XX S HOYNE AVE  031A
#
#   Primary Type                     Description Location Description  Arrest  \
# 0      ROBBERY   ARMED: OTHER DANGEROUS WEAPON         CTA PLATFORM   False
# 1      ASSAULT             AGGRAVATED: HANDGUN             SIDEWALK   False
# 2      ASSAULT  AGG PRO.EMP:KNIFE/CUTTING INST          GAS STATION   False
# 3      ASSAULT       AGGRAVATED: OTHER FIREARM             SIDEWALK    True
# 4      ROBBERY                  ARMED: HANDGUN               STREET   False
#
#    Domestic  ...  Ward  Community Area  FBI Code  X Coordinate Y Coordinate  \
# 0     False  ...  25.0            28.0        03     1172803.0    1898062.0
# 1     False  ...  18.0            70.0       04A     1150185.0    1851851.0
# 2     False  ...  16.0            68.0       04A     1171833.0    1865730.0
# 3     False  ...  13.0            64.0       04A     1137767.0    1863898.0
# 4     False  ...  18.0            71.0        03     1163724.0    1852701.0
#
#    Year              Updated On   Latitude  Longitude  \
# 0  2018  01/10/2019 03:16:50 PM  41.875718 -87.640994
# 1  2018  01/10/2019 03:16:50 PM  41.749379 -87.725239
# 2  2018  01/10/2019 03:16:50 PM  41.787017 -87.645506
# 3  2018  01/10/2019 03:16:50 PM  41.782670 -87.770456
# 4  2018  01/10/2019 03:16:50 PM  41.751438 -87.675603
#
#                         Location
# 0   (41.875717757, -87.64099364)
# 1   (41.74937879, -87.725239484)
# 2   (41.78701723, -87.645505595)
# 3   (41.782669846, -87.77045603)
# 4  (41.751438029, -87.675602996)
#
# [5 rows x 22 columns]

# %% [markdown]
# # TRANSFORM CHICAGO CRIME DATA

# %%
#Drop crime_df columns: ID, Case Number, Block, IUCR, Domestic, Ward, X Coordinate, Y Coordinate, Year, Updated On, Latitude, Longitude, Location
crime = crime_df.drop(columns=['ID', 'Case Number', 'Block', 'IUCR', 'Domestic', 'Ward', 'X Coordinate',
                         'Y Coordinate', 'Year', 'Updated On', 'Latitude', 'Longitude', 'Location',
                         'District', 'Community Area', 'FBI Code', 'Arrest', 'Beat'], axis=1)
crime.head()
# Out:
#                      Date Primary Type                     Description  \
# 0  12/31/2018 11:30:00 PM      ROBBERY   ARMED: OTHER DANGEROUS WEAPON
# 1  12/31/2018 11:27:00 PM      ASSAULT             AGGRAVATED: HANDGUN
# 2  12/31/2018 10:50:00 PM      ASSAULT  AGG PRO.EMP:KNIFE/CUTTING INST
# 3  12/31/2018 10:33:00 PM      ASSAULT       AGGRAVATED: OTHER FIREARM
# 4  12/31/2018 10:07:00 PM      ROBBERY                  ARMED: HANDGUN
#
#   Location Description
# 0         CTA PLATFORM
# 1             SIDEWALK
# 2          GAS STATION
# 3             SIDEWALK
# 4               STREET

# %% [markdown]
# # EXTRACT CHICAGO WEATHER DATA (JSON)

# %%
#Import Weather JSON file

weather_df = pd.read_json('chicago_weather.json', orient='columns')
weather_df.head()
# Out:
#    city_id       clouds          dt                         dt_iso  \
# 0  4887398  {'all': 90}  1483228800  2017-01-01 00:00:00 +0000 UTC
# 1  4887398  {'all': 40}  1483232400  2017-01-01 01:00:00 +0000 UTC
# 2  4887398   {'all': 1}  1483236000  2017-01-01 02:00:00 +0000 UTC
# 3  4887398   {'all': 1}  1483239600  2017-01-01 03:00:00 +0000 UTC
# 4  4887398   {'all': 1}  1483243200  2017-01-01 04:00:00 +0000 UTC
#
#                                                 main rain snow  \
# 0  {'temp': 274.06, 'temp_min': 273.15, 'temp_max...  NaN  NaN
# 1  {'temp': 272.94, 'temp_min': 271.15, 'temp_max...  NaN  NaN
# 2  {'temp': 272.14, 'temp_min': 271.15, 'temp_max...  NaN  NaN
# 3  {'temp': 270.97, 'temp_min': 270.15, 'temp_max...  NaN  NaN
# 4  {'temp': 270.14, 'temp_min': 269.15, 'temp_max...  NaN  NaN
#
#                                              weather                      wind
# 0  [{'id': 804, 'main': 'Clouds', 'description': ...  {'speed': 4, 'deg': 300}
# 1  [{'id': 802, 'main': 'Clouds', 'description': ...  {'speed': 4, 'deg': 290}
# 2  [{'id': 800, 'main': 'Clear', 'description': '...  {'speed': 3, 'deg': 270}
# 3  [{'id': 800, 'main': 'Clear', 'description': '...  {'speed': 3, 'deg': 250}
# 4  [{'id': 800, 'main': 'Clear', 'description': '...  {'speed': 1, 'deg': 220}

# %% [markdown]
# # TRANSFORM CHICAGO WEATHER DATA

# %%
weather = weather_df.drop(columns=['city_id', 'weather', 'clouds', 'dt'], axis=1)
weather.rename(columns={'dt_iso': 'date', 'main': 'temp'}, inplace=True)

# %%
# Extract date, Max Temp, Min Temp, Windspeed

#Strip date
dates=[]
for row in weather['date']:
    dates.append(row[:10])

#Strip max and min temperatures, convert from Kelvin to Fahrenheit
max_temp =[]
min_temp =[]
for row in weather['temp']:
    max_temp.append(9/5 * (row['temp_max']-273)+32)
    min_temp.append(9/5 * (row['temp_min']-273)+32)

#Strip wind category
winds = []
for row in weather['wind']:
    winds.append(row['speed'])

#Add new lists to weather dataframe. Convert Kelvin temperature to Fahrenheit
weather['dates'] = dates
weather['max_temp'] = max_temp
weather['min_temp'] = min_temp
weather['winds'] = winds

#Drop old columns from dataframe
weather_clean = weather.drop(columns=['date', 'temp', 'rain', 'snow', 'wind'], axis=1)
weather_clean.head()
# Out:
#         dates  max_temp  min_temp  winds
# 0  2017-01-01     35.87     32.27      4
# 1  2017-01-01     34.07     28.67      4
# 2  2017-01-01     32.27     28.67      3
# 3  2017-01-01     30.47     26.87      3
# 4  2017-01-01     28.67     25.07      1
