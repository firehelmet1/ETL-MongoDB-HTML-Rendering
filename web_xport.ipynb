# %%
import pandas as pd
import os
import json

# %%
chicago_final_df = pd.read_json('C:\\Users\\JS\\repos\\ETL-Project\\etl_project\\chicago_final.json')

# %%
chicago_final_html = chicago_final_df.T

# %%
chicago_final_html.to_html('chicago_data.html')

# %%
chicago_final_html
# Out:
#       Dates Robbery Assault Sexual Assault max_temp min_temp    winds Crashes  \
# 0   2017-01    1075    1373            154   32.195  27.7893  4.01882    8670
# 1   2017-02     787    1295            124  39.1882  35.3337  4.34375    8274
# 2   2017-03     783    1486            105  42.0429  36.3647  4.95565   10220
# 3   2017-04     851    1638            146  57.3875    50.45  4.58611   10114
# 4   2017-05     903    1853            133  61.4305  54.6248  4.41935   11727
# 5   2017-06     981    1857            117  75.2872  68.7497  3.82222   12561
# 6   2017-07    1004    1821            162  77.2878    70.77  3.02554   13789
# 7   2017-08    1174    1739            159  73.3671  66.9776  2.95565   15625
# 8   2017-09    1002    1786            145  71.5918  64.2293  3.13472   18485
# 9   2017-10    1119    1628            148  59.9367  54.8053  3.93683   20385
# 10  2017-11    1128    1454            123  43.2989  37.6289  3.96389   19329
# ...
